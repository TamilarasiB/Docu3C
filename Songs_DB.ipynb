# %%
import os
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv("/content/songsFrequency.csv")

# %%
dataset
# Out:
#                             MOVIE NAME   YEAR   MALE SINGER COUNT  \
# 0                   Raabta (film)_2017   2017                   5
# 1                    Luv U Soniyo_2013   2013                   4
# 2                        Sahibaan_1993   1993                   2
# 3     Baap Numbri Beta Dus Numbri_1990   1990                   1
# 4                Jyoti Bane Jwala_1980   1980                   3
# ...                                ...    ...                 ...
# 2444              Jhoota Kahin Ka_1979   1979                   2
# 2445                 Ghar Ki Laaj_1993   1993                   3
# 2446                Chandra Mukhi_1993   1993                   3
# 2447               Jai Bangladesh_1971   1971                   2
# 2448                Cinema Cinema_1979   1979                   0
#
#        FEMALE SINGER COUNT   MALE SONG COUNT   FEMALE SONG COUNT
# 0                        2                 8                   2
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2449 entries, 0 to 2448
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   MOVIE NAME            2449 non-null   object
#  1    YEAR                 2449 non-null   int64
#  2    MALE SINGER COUNT    2449 non-null   int64
#  3    FEMALE SINGER COUNT  2449 non-null   int64
#  4    MALE SONG COUNT      2449 non-null   int64
#  5    FEMALE SONG COUNT    2449 non-null   int64
# dtypes: int64(5), object(1)
# memory usage: 114.9+ KB

# %%
dataset.describe()
# Out:
#               YEAR   MALE SINGER COUNT   FEMALE SINGER COUNT  \
# count  2449.000000         2449.000000           2449.000000
# mean   1990.988158            2.351164              2.115966
# std      13.902477            1.684221              1.206103
# min    1970.000000            0.000000              0.000000
# 25%    1980.000000            1.000000              1.000000
# 50%    1990.000000            2.000000              2.000000
# 75%    1999.000000            3.000000              3.000000
# max    2017.000000           12.000000              8.000000
#
#         MALE SONG COUNT   FEMALE SONG COUNT
# count       2449.000000         2449.000000
# mean           4.237240            4.336056
# std            3.048971            2.670067
# min            0.000000            0.000000
# 25%            2.000000            2.000000
# 50%            4.000000            4.000000
# 75%            6.000000            6.000000
# max           25.000000           20.000000

# %%
dataset.isnull().sum()
# Out:
# MOVIE NAME              0
#  YEAR                   0
#  MALE SINGER COUNT      0
#  FEMALE SINGER COUNT    0
#  MALE SONG COUNT        0
#  FEMALE SONG COUNT      0
# dtype: int64

# %%
dataset.isna().sum()
# Out:
# MOVIE NAME              0
#  YEAR                   0
#  MALE SINGER COUNT      0
#  FEMALE SINGER COUNT    0
#  MALE SONG COUNT        0
#  FEMALE SONG COUNT      0
# dtype: int64

# %%
dataset.dtypes
# Out:
# MOVIE NAME              object
#  YEAR                    int64
#  MALE SINGER COUNT       int64
#  FEMALE SINGER COUNT     int64
#  MALE SONG COUNT         int64
#  FEMALE SONG COUNT       int64
# dtype: object

# %%
dataset.count()
# Out:
# MOVIE NAME              2449
#  YEAR                   2449
#  MALE SINGER COUNT      2449
#  FEMALE SINGER COUNT    2449
#  MALE SONG COUNT        2449
#  FEMALE SONG COUNT      2449
# dtype: int64

# %%
from matplotlib import pyplot as plt
dataset[' FEMALE SINGER COUNT'].plot(kind='hist', bins=20, title=' FEMALE SINGER COUNT')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
dataset[' MALE SINGER COUNT'].plot(kind='hist', bins=20, title=' MALE SINGER COUNT')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
dataset.rename(columns={"YEAR":"Year","MALE SINGER COUNT":"Male_Singer","FEMALE SINGER COUNT":"Female_Singer","MALE SONG COUNT":"Male_Song", "FEMALE SONG COUNT":"Female_Song"},inplace=True)

# %%
dataset["TOTAL SINGERS"] = dataset[' FEMALE SINGER COUNT'] + dataset[" MALE SINGER COUNT"]

# %%
dataset["TOTAL SONGS"] = dataset[' FEMALE SONG COUNT'] + dataset[" MALE SONG COUNT"]

# %%
dataset
# Out:
#                             MOVIE NAME   YEAR   MALE SINGER COUNT  \
# 0                   Raabta (film)_2017   2017                   5
# 1                    Luv U Soniyo_2013   2013                   4
# 2                        Sahibaan_1993   1993                   2
# 3     Baap Numbri Beta Dus Numbri_1990   1990                   1
# 4                Jyoti Bane Jwala_1980   1980                   3
# ...                                ...    ...                 ...
# 2444              Jhoota Kahin Ka_1979   1979                   2
# 2445                 Ghar Ki Laaj_1993   1993                   3
# 2446                Chandra Mukhi_1993   1993                   3
# 2447               Jai Bangladesh_1971   1971                   2
# 2448                Cinema Cinema_1979   1979                   0
#
#        FEMALE SINGER COUNT   MALE SONG COUNT   FEMALE SONG COUNT  \
# 0                        2                 8                   2
# ...

# %%
from matplotlib import pyplot as plt
dataset.plot(kind='scatter', x=' YEAR', y=' MALE SINGER COUNT', s=32, alpha=.8, title='Male Singer Count')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
dataset.plot(kind='scatter', x=' YEAR', y=' FEMALE SINGER COUNT', s=32, alpha=.8, title='Female Singer Count')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
dataset.plot(kind='scatter', x=' MALE SONG COUNT', y=' FEMALE SONG COUNT', s=32, alpha=.8, title='Male Song vs Female Song')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
dataset.plot(kind='scatter', x=' MALE SINGER COUNT', y=' FEMALE SINGER COUNT', s=32, alpha=.8, title='Male Singer  vs Female Singer')
plt.gca().spines[['top', 'right',]].set_visible(False)
