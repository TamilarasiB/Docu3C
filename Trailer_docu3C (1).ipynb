# %%
import os
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv ("/content/complete-data.csv")

# %%
dataset
# Out:
#        frame_number gender   emotion  year    movie_name
# 0                28  woman     happy  2014  dedh_ishqiya
# 1                62  woman     happy  2014  dedh_ishqiya
# 2                60    man     angry  2014  dedh_ishqiya
# 3                60    man       sad  2014  dedh_ishqiya
# 4                60    man     angry  2014  dedh_ishqiya
# ...             ...    ...       ...   ...           ...
# 32192            18    man     happy  2016   housefull_3
# 32193            25    man   neutral  2016   housefull_3
# 32194            25    man   neutral  2016   housefull_3
# 32195            25    man     happy  2016   housefull_3
# 32196            31    man  surprise  2016   housefull_3
#
# [32197 rows x 5 columns]

# %%
from matplotlib import pyplot as plt
import seaborn as sns
dataset.groupby('emotion').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(dataset['emotion'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(dataset, x='frame_number', y='emotion', inner='box', palette='Dark2')
sns.violinplot(title='Emotion vs Year')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-12-feafbd23c6ca>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(dataset, x='frame_number', y='emotion', inner='box', palette='Dark2')

# %%
dataset.shape
# Out:
# (32197, 5)

# %%
dataset.dtypes
# Out:
# frame_number     int64
# gender          object
# emotion         object
# year             int64
# movie_name      object
# dtype: object

# %%
dataset.describe()
# Out:
#        frame_number          year
# count  32197.000000  32197.000000
# mean      89.766189   2013.555052
# std       82.595545      2.545130
# min        0.000000   2008.000000
# 25%       45.000000   2012.000000
# 50%       77.000000   2014.000000
# 75%      115.000000   2016.000000
# max      942.000000   2017.000000

# %%
data_woman=dataset[dataset["gender"]=="woman"]
data_man=dataset[dataset["gender"]=="man"]

# %%
data_woman
# Out:
#        frame_number gender  emotion  year    movie_name
# 0                28  woman    happy  2014  dedh_ishqiya
# 1                62  woman    happy  2014  dedh_ishqiya
# 6               132  woman    happy  2014  dedh_ishqiya
# 8                61  woman      sad  2014  dedh_ishqiya
# 15               35  woman      sad  2014  dedh_ishqiya
# ...             ...    ...      ...   ...           ...
# 32177            32  woman    happy  2016   housefull_3
# 32178            47  woman      sad  2016   housefull_3
# 32183           159  woman     fear  2016   housefull_3
# 32190           112  woman  neutral  2016   housefull_3
# 32191            72  woman    happy  2016   housefull_3
#
# [10155 rows x 5 columns]

# %%
from matplotlib import pyplot as plt
data_woman['year'].plot(kind='hist', bins=20, title='year')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
data_man
# Out:
#        frame_number gender   emotion  year    movie_name
# 2                60    man     angry  2014  dedh_ishqiya
# 3                60    man       sad  2014  dedh_ishqiya
# 4                60    man     angry  2014  dedh_ishqiya
# 5               111    man       sad  2014  dedh_ishqiya
# 7                94    man       sad  2014  dedh_ishqiya
# ...             ...    ...       ...   ...           ...
# 32192            18    man     happy  2016   housefull_3
# 32193            25    man   neutral  2016   housefull_3
# 32194            25    man   neutral  2016   housefull_3
# 32195            25    man     happy  2016   housefull_3
# 32196            31    man  surprise  2016   housefull_3
#
# [22042 rows x 5 columns]

# %%
from matplotlib import pyplot as plt
data_man['year'].plot(kind='hist', bins=20, title='year')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
woman_frames = data_woman.groupby(by=['year'])['frame_number'].count().to_frame(name = 'count').reset_index()
man_frames = data_man.groupby(by=['year'])['frame_number'].count().to_frame(name = 'count').reset_index()

# %%
woman_frames
# Out:
#    year  count
# 0  2008    396
# 1  2009    377
# 2  2010    707
# 3  2011    978
# 4  2012    659
# 5  2013   1070
# 6  2014   1624
# 7  2015   1482
# 8  2016   1543
# 9  2017   1319

# %%
man_frames
# Out:
#    year  count
# 0  2008    852
# 1  2009    966
# 2  2010   1600
# 3  2011   1999
# 4  2012   1633
# 5  2013   2327
# 6  2014   3874
# 7  2015   2959
# 8  2016   2963
# 9  2017   2869
